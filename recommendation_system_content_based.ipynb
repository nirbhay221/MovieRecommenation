# %% [markdown]
# <a href="https://colab.research.google.com/github/nirbhay221/MovieRecommenation/blob/master/recommendation_system_content_based.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("movie_dataset.csv")
features = ["keywords","cast","genres","director"]
for feature in features:
  df[feature] = df[feature].fillna(" ")


def combined_features(row):
  try:
    return row["keywords"]+" "+row["cast"]+" "+row["genres"]+" "+row["director"]
  except:
    print(row)
df["combined_features"]= df.apply(combined_features,axis=1)

# %%
df.iloc[0]["combined_features"]
# Out:
# 'culture clash future space war space colony society Sam Worthington Zoe Saldana Sigourney Weaver Stephen Lang Michelle Rodriguez Action Adventure Fantasy Science Fiction James Cameron'

# %%
 text = df["combined_features"]
 count =CountVectorizer()
 count_matrix = count.fit_transform(text)
 similarity = cosine_similarity(count_matrix)
 cosine_model_df = pd.DataFrame(similarity,index =df["title"] ,columns=df["title"])
 cosine_model_df
# Out:
# title                                       Avatar  ...  My Date with Drew
# title                                               ...
# Avatar                                    1.000000  ...            0.00000
# Pirates of the Caribbean: At World's End  0.105409  ...            0.00000
# Spectre                                   0.120386  ...            0.00000
# The Dark Knight Rises                     0.037743  ...            0.00000
# John Carter                               0.230940  ...            0.00000
# ...                                            ...  ...                ...
# El Mariachi                               0.075485  ...            0.00000
# Newlyweds                                 0.000000  ...            0.00000
# Signed, Sealed, Delivered                 0.000000  ...            0.04264
# Shanghai Calling                          0.000000  ...            0.00000
# My Date with Drew                         0.000000  ...            1.00000
#
# ...

# %%
def make_recommendation(movie_user_likes):
  return cosine_model_df[movie_user_likes].sort_values(ascending =False)
make_recommendation("Aliens")
# Out:
# title
# Aliens                                   1.000000
# The Terminator                           0.480384
# Alien                                    0.415168
# Avatar                                   0.377426
# The Box                                  0.376309
#                                            ...
# How She Move                             0.000000
# My Life in Ruins                         0.000000
# The Adventures of Elmo in Grouchland     0.000000
# Larry the Cable Guy: Health Inspector    0.000000
# My Date with Drew                        0.000000
# Name: Aliens, Length: 4803, dtype: float64
